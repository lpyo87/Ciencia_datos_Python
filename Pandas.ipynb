# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.Series(np.random.rand(8), index= np.arange(10,90,10))
# Out:
# 10    0.802016
# 20    0.203933
# 30    0.775486
# 40    0.300080
# 50    0.898622
# 60    0.413074
# 70    0.241329
# 80    0.934684
# dtype: float64

# %%
pd.Series(np.random.rand(8), index= ['A','B','C','D','E','F','G','H'])
# Out:
# A    0.733806
# B    0.608914
# C    0.715587
# D    0.378600
# E    0.173781
# F    0.932708
# G    0.997854
# H    0.157488
# dtype: float64

# %%
diccionario = {'A':20,'B':'hola','c':40,'arroz':'blanco'}
diccionario
# Out:
# {'A': 20, 'B': 'hola', 'c': 40, 'arroz': 'blanco'}

# %%
pd.Series(diccionario)
# Out:
# A            20
# B          hola
# c            40
# arroz    blanco
# dtype: object

# %%
d={'columnaA':[10,20,30,40,50],
   'columnaB': pd.Series(['abc',45,70,90,'gfk'], index =[2000,2001,2002,2003,2004]),
   'columnaC':np.array([True, False, False,True, True])}
df1 = pd.DataFrame(d, index =[2000,2001,2002,2003,2004])
df1
# Out:
#       columnaA columnaB  columnaC
# 2000        10      abc      True
# 2001        20       45     False
# 2002        30       70     False
# 2003        40       90      True
# 2004        50      gfk      True

# %%
type(df1['columnaA'])
# Out:
# pandas.core.series.Series

# %%
df1[['columnaC','columnaA']]
# Out:
#       columnaC  columnaA
# 2000      True        10
# 2001     False        20
# 2002     False        30
# 2003      True        40
# 2004      True        50

# %% [markdown]
# Sirve para hacer localizaciones en dataframes con nombres de filas y columnas

# %%
df1.loc[[2004,2001],['columnaC','columnaA']]
# Out:
#       columnaC  columnaA
# 2004      True        50
# 2001     False        20

# %% [markdown]
# Sirve para hacer localizaciones en dataframes con posiciones de filas y columnas

# %%
df1.iloc[[4,1],[2,0]]
# Out:
#       columnaC  columnaA
# 2004      True        50
# 2001     False        20

# %% [markdown]
# #### Operaciones básicas

# %%
df1['Nueva_col']=df1['columnaA']**2
df1
# Out:
#       columnaA columnaB  columnaC  Nueva_col
# 2000        10      abc      True        100
# 2001        20       45     False        400
# 2002        30       70     False        900
# 2003        40       90      True       1600
# 2004        50      gfk      True       2500

# %% [markdown]
# Al momento de realizar un drop de columnas, se tiene que incluir el número de axis para poder garantizar que se elimine ya sea la columna y no la fila. Si se utiliza el parámetro inplace = True, se reemplazan los datos

# %%
df1.drop('Nueva_col', axis=1, inplace=True)

# %%
df1
# Out:
#       columnaA columnaB  columnaC
# 2000        10      abc      True
# 2001        20       45     False
# 2002        30       70     False
# 2003        40       90      True
# 2004        50      gfk      True

# %%
df1['fecha']=['20/2/2022','15/3/2022','7/7/2022','3/9/2018','4/9/1998']

# %%
df1
# Out:
#       columnaA columnaB  columnaC      fecha
# 2000        10      abc      True  20/2/2022
# 2001        20       45     False  15/3/2022
# 2002        30       70     False   7/7/2022
# 2003        40       90      True   3/9/2018
# 2004        50      gfk      True   4/9/1998

# %%
df1.reset_index(inplace=True)
df1
# Out:
#    index  columnaA columnaB  columnaC      fecha
# 0   2000        10      abc      True  20/2/2022
# 1   2001        20       45     False  15/3/2022
# 2   2002        30       70     False   7/7/2022
# 3   2003        40       90      True   3/9/2018
# 4   2004        50      gfk      True   4/9/1998

# %%
df1.set_index('fecha', inplace=True)
df1
# Out:
#            index  columnaA columnaB  columnaC
# fecha
# 20/2/2022   2000        10      abc      True
# 15/3/2022   2001        20       45     False
# 7/7/2022    2002        30       70     False
# 3/9/2018    2003        40       90      True
# 4/9/1998    2004        50      gfk      True

# %%
df1
# Out:
#            index  columnaA columnaB  columnaC
# fecha
# 20/2/2022   2000        10      abc      True
# 15/3/2022   2001        20       45     False
# 7/7/2022    2002        30       70     False
# 3/9/2018    2003        40       90      True
# 4/9/1998    2004        50      gfk      True

# %% [markdown]
# #### Cargando archivo

# %%
dataset= pd.read_csv("hotel_bookings.csv")
dataset
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
dataset.head
# Out:
# <bound method NDFrame.head of                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
dataset.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
dataset.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# ## Filtros

# %%
dataset[dataset['country']== 'FRA']
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 18      Resort Hotel            0          0               2015
# 80      Resort Hotel            0         99               2015
# 101     Resort Hotel            0         98               2015
# 102     Resort Hotel            0         92               2015
# 127     Resort Hotel            0        100               2015
# ...              ...          ...        ...                ...
# 119263    City Hotel            0        115               2017
# 119286    City Hotel            0        177               2017
# 119288    City Hotel            0         44               2017
# 119312    City Hotel            0          4               2017
# 119386    City Hotel            0        102               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 18                   July                        27
# 80                   July                        27
# ...

# %%
dataset[(dataset['country']== 'FRA') &
         (dataset['children']==0) &
         (dataset['babies']==0)]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 18      Resort Hotel            0          0               2015
# 80      Resort Hotel            0         99               2015
# 101     Resort Hotel            0         98               2015
# 127     Resort Hotel            0        100               2015
# 129     Resort Hotel            0        100               2015
# ...              ...          ...        ...                ...
# 119263    City Hotel            0        115               2017
# 119286    City Hotel            0        177               2017
# 119288    City Hotel            0         44               2017
# 119312    City Hotel            0          4               2017
# 119386    City Hotel            0        102               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 18                   July                        27
# 80                   July                        27
# ...

# %%
dataset[dataset['country'].isin(['FRA','GER'])]

# %%
dataset[(dataset['country'] == 'FRA')|(dataset['country'] == 'GER')]

# %% [markdown]
# Análisis estadísticos descriptivos

# %%
dataset.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
dataset['market_segment'].value_counts()
# Out:
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: market_segment, dtype: int64

# %%
group_country=dataset.groupby('country')

# %%
group_country.sum()['adults']
# Out:
# C:\Users\lgutierrez\AppData\Local\Temp\ipykernel_13844\4190547926.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_country.sum()['adults']
# country
# ABW      5
# AGO    570
# AIA      2
# ALB     21
# AND     15
#       ...
# VGB      2
# VNM     17
# ZAF    143
# ZMB      4
# ZWE      8
# Name: adults, Length: 177, dtype: int64

# %%
group_country.agg(
    media_adultos = ('adults', np.mean),
    suma_adultos = ('adults', np.sum),
    suma_children = ('children', np.sum),
    media_children = ('children', np.mean)
)

# %%
dataset.groupby(['hotel','deposit_type']).agg(
        media_adultos = ('adults', np.mean),
    suma_adultos = ('adults', np.sum)
)
# Out:
#                            media_adultos  suma_adultos
# hotel        deposit_type
# City Hotel   No Deposit         1.860119        123590
#              Non Refund         1.803621         23209
#              Refundable         1.950000            39
# Resort Hotel No Deposit         1.866908         71314
#              Non Refund         1.869692          3214
#              Refundable         1.901408           270

# %%
def getDFDataTypes(dataset):
    continuas = []
    discretas = []
    categoricas = []
    for columnName in dataset.columns.values:
        tipoDato = dataset[columnName].dtype
        if((tipoDato == 'int64') or (tipoDato == 'float64')):
            if(len(dataset[columnName].unique()) <= 30):
                discretas.append(columnName)
            else:
                continuas.append(columnName)
        else:
            categoricas.append(columnName)
    return continuas, discretas, categoricas

# %% [markdown]
# Si la cantidad de elemenos distintos es menor a 30, se considera discreta. Sino, contínua

# %%
len(dataset['lead_time'].unique())
# Out:
# 479

# %%
continuas, discretas, categoricas = getDFDataTypes(dataset)

# %%
continuas
# Out:
# ['is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'booking_changes',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests']

# %%
categoricas
# Out:
# ['hotel',
#  'arrival_date_month',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'reserved_room_type',
#  'assigned_room_type',
#  'deposit_type',
#  'customer_type',
#  'reservation_status',
#  'reservation_status_date']

# %%
for continueVar in continuas:
    print(continueVar)
    dataset[continueVar].plot(kind='density')
    plt.show()
# Out:
# lead_time
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[74], line 3
#       1 for continueVar in continuas:
#       2     print(continueVar)
# ----> 3     dataset[continueVar].plot(kind='density')
#       4     plt.show()
#
# File c:\Users\lgutierrez\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\lgutierrez\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
# ...

# %%
for continueVar in continuas:
     print(continueVar)
     print(f"Media: {dataset[continueVar].mean()} ")
     print(f"Mediaana: {dataset[continueVar].median()} ")
     print(f"Maximo: {dataset[continueVar].max()} ")
     print(f"Minimo: {dataset[continueVar].min()} ")
     print(f"Desviación: {dataset[continueVar].std()} ")
     print(f"Varianza: {dataset[continueVar].var()} ")
     dataset[continueVar].plot(kind='density')
     plt.show()
     print("--------------------------------")
# Out:
# lead_time
# Media: 104.01141636652986
# Mediaana: 69.0
# Maximo: 737
# Minimo: 0
# Desviación: 106.86309704798794
# Varianza: 11419.721510687687
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[75], line 9
#       7 print(f"Desviación: {dataset[continueVar].std()} ")
#       8 print(f"Varianza: {dataset[continueVar].var()} ")
# ----> 9 dataset[continueVar].plot(kind='density')
#      10 plt.show()
#      11 print("--------------------------------")
#
# File c:\Users\lgutierrez\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...
